# %%
import os ########################################
import numpy as np ###############################
import scipy.stats as stats ######################
import math ######################################
import matplotlib.pyplot as plt###################

# %%
nyx_comp1_error = np.array([0.05006061346764866,0.0404966737774214,0.0302556091698821])
nyx_comp1_storage = np.array([4.044,4.864,6.623])
nyx_comp3_error = np.array([0.031217406924893,0.0300997497690161,0.0285781648083591])
nyx_comp3_storage = np.array([5.455,6.406,8.554])
nyx_comp5_error = np.array([0.030116027192903,0.0293317680984235,0.0280119786972316])
nyx_comp5_storage = np.array([6.865,7.948,10.488])
nyx_sz_low_error = np.array([0.0000000125])
nyx_sz_low_storage = np.array([49.06])
nyx_sz_high_error = np.array([0.0906120184591155])
nyx_sz_high_storage = np.array([11.231])

# %%
# Globel Climate
# number of sharing bins
# Number of total bins: 477763

Num_of_clusters = np.array([0, 1109, 2187, 4545, 9505, 18252])
Num_of_shareBins = np.array([0,244698, 275282, 310719, 338881, 355934])
Num_of_modeling_bins = 477763-Num_of_shareBins+Num_of_clusters

plt.title('Global Climate')
plt.plot(Num_of_clusters, Num_of_modeling_bins, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Number of modeled bins')

# for x,y in zip(Num_of_clusters, Num_of_modeling_bins):
#     # label_text = '({x}, {y})'.format(x=x,y=y)
#     plt.text(x,y-2000, y, ha='left', va='bottom', fontsize=10)
plt.show()

# %%
# Nyx
# number of sharing bins
# Number of total bins: 417472

Num_of_clusters = np.array([0,294, 349, 1355, 2527])
Num_of_shareBins = np.array([0,217979, 247967, 267368, 265279])
Num_of_modeling_bins = 417472-Num_of_shareBins+Num_of_clusters

plt.title('Nyx')
plt.plot(Num_of_clusters, Num_of_modeling_bins, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Number of modeled bins')

# for x,y in zip(Num_of_clusters, Num_of_modeling_bins):
#     # label_text = '({x}, {y})'.format(x=x,y=y)
#     plt.text(x,y-2000, y, ha='left', va='bottom', fontsize=10)
plt.show()

# %%
# Red sea
# number of sharing bins
# Number of total bins: 1765559

Num_of_clusters = np.array([0, 2331, 6325, 24569, 60989, 198737])
Num_of_shareBins = np.array([0, 813442, 990060, 1109492, 1204488, 1364919])
Num_of_modeling_bins = 1765559-Num_of_shareBins+Num_of_clusters

plt.title('Red Sea')
# plt.plot(Num_of_clusters, Num_of_shareBins, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Number of sharing bins')

plt.plot(Num_of_clusters, Num_of_modeling_bins, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Number of modeled bins')
comp = [3,5,7,9,12,15]


# for x,y,i in zip(Num_of_clusters, Num_of_modeling_bins, comp):
#     # label_text = '({x}, {y})'.format(x=x,y=y)
#     # plt.text(x, y-10000, y, ha='left', va='bottom', fontsize=10)
    # plt.plot(x, y, marker='o', markersize=i, c = 'blue')
plt.show()

# %%
X = ['Nyx','Global Climate','Red Sea']
Raw = [173.377,359.473,777.199]
SZ_low = [49.06,90.66,132.906]
SZ_high = [11.231,28.693,38.62]
our_method = [8.554,19.752,29.001]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, Raw, 0.2, label = 'RAW')
plt.bar(X_axis - 0, SZ_low, 0.2, label = 'SZ low error')
plt.bar(X_axis + 0.2, SZ_high, 0.2, label = 'SZ high error')
plt.bar(X_axis + 0.4, our_method, 0.2, label = 'Our approach')
plt.title('Storage comparison')
plt.xticks(X_axis, X)
plt.ylabel("Storage (MB)")
plt.legend()
plt.show()

# %%
plt.title('Nyx')
plt.plot(nyx_comp1_storage, nyx_comp1_error, marker='o', label='Comp 1')
plt.plot(nyx_comp3_storage, nyx_comp3_error, marker='o', label='Comp 3')
plt.plot(nyx_comp5_storage, nyx_comp5_error, marker='o', label='Comp 5')
plt.xlabel('Storage (MB)')
plt.ylabel('RMSE')
plt.yscale('log')
plt.legend()
plt.show()

# %%
air_comp3_error = np.array([0.0491757983022327,0.0480869165628025,0.0417234436171254])
air_comp3_storage = np.array([6.171,10.626,14.785])

air_comp5_error = np.array([0.0488065582354956,0.0387390376571105,0.0290961963076723])
air_comp5_storage = np.array([7.737,12.484,17.255])

air_comp7_error = np.array([0.0468442396618704,0.0294942139660126,0.0271091199702987])
air_comp7_storage = np.array([9.303,14.485,19.752])

# %%
plt.title('Global climate')
# plt.plot(redsea_inter_storage, redsea_inter_error, marker='o', label='Comp 5')
plt.plot(air_comp7_storage, air_comp7_error, marker='o', label='Comp 7')
plt.plot(air_comp3_storage, air_comp3_error, marker='o', label='Comp 3')
plt.plot(air_comp5_storage, air_comp5_error, marker='o', label='Comp 5')
plt.xlabel('Storage (MB)')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
#thres compare
thres = [3,5,7,9]
thres_size = [3,6,9,12]

# climate_error = np.array([0.0469441333333841,0.0471152678051705,0.0471992711167049,0.0472591058481787])
# climate_storage = np.array([15.588908,11.85788,10.327148,9.390716])

# Nyx_error = np.array([0.0296610073515932,0.029842327347302,0.0300314731177651,0.0302568389713411])
# Nyx_storage = np.array([16.062332,13.8428,12.262088,10.648784])

Redsea_error = np.array([0.01090559053274839,0.010962234198423572,0.010989321210757732,0.011004532651218864])
Redsea_storage = np.array([21.556084,18.269428,16.780948,16.089184])

plt.title('Red Sea')
# plt.plot(climate_storage, climate_error, label='Global Climate', marker='o',markersize=0)
# plt.plot(Nyx_storage, Nyx_error, marker='o', label='Nyx',markersize=0)
plt.plot(Redsea_storage, Redsea_error, marker='o', label='Red Sea', markersize=0)
plt.xlabel('Storage(MB)')
plt.ylabel('RMSE')


# for x,y,t, i in zip(climate_storage, climate_error,thres, thres_size):
#     plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
    # text = "threshold: {t}".format(t=t)
    # plt.text(x, y, text, ha='left', va='bottom', fontsize=10)
# for x,y,t,i in zip(Nyx_storage, Nyx_error, thres,thres_size):
#     plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
#     text = "threshold: {t}".format(t=t)
#     plt.text(x, y, text, ha='left', va='bottom', fontsize=10)
    # plt.plot(x, y, marker='o', markersize=i, c = '#ff7f0e')
for x,y,t,i in zip(Redsea_storage, Redsea_error, thres, thres_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
#     text = "threshold: {t}".format(t=t)
#     plt.text(x, y, text, ha='left', va='bottom', fontsize=10)

plt.yscale('log')
plt.legend()
plt.show()

# %%
# Global climate tradeoff
# comps = [1,3,5,7]
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

Sz_error = np.array([0.0889391198098206])
Sz_storage = np.array([39.059])

interp_error = np.array([0.0608424490879426,0.0593215111027358,0.057167255458251,0.0556085172601324])
interp_storage = np.array([7.588,14.13,21.722,35.97])

nonshare_error = np.array([0.0496391480022798,0.0491081423039642,0.0486795680611637,0.0466286733007518])
nonshare_storage = np.array([9.55526,21.021572,32.487884,43.954196])

share_error = np.array([0.0474242411781826,0.0430768206503382,0.0310757548032218,0.0294359541925025])
share_storage = np.array([9.19382,14.70788,17.122952,19.538024])

plt.title('Global Climate')
plt.plot(interp_storage, interp_error, marker='o', label='interp')
plt.plot(Sz_storage, Sz_error, marker='o', label='SZ')
plt.plot(nonshare_storage, nonshare_error, marker='o', label='Ours(nonshare)', markersize=3)
plt.plot(share_storage, share_error, marker='o', label='Ours(share temporal)', markersize=3)
plt.xlabel('Storage(MB)')
plt.ylabel('RMSE')
comps_size = [3,6,9,12]

# for x,y,i in zip(interp_storage, interp_error, comps_size):
#     plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
for x,y,i in zip(nonshare_storage, nonshare_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#2ca02c')
for x,y,i in zip(share_storage, share_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#d62728')

plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
# Nyx compare thradeoff
# comps = [1,3,5,7]
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

Sz_error = np.array([0.0906120184591155])
Sz_storage = np.array([11.231])

interp_error = np.array([0.0483185130567818,0.040382792559371,0.03563953794681089,0.031615687775990574])
interp_storage = np.array([9.564,17.313,22.480816,34.37])

nonshare_error = np.array([0.0405202037425524,0.0310794657913169,0.0298488186774964,0.0292856501160722])
nonshare_storage = np.array([10.2339,18.368768,28.388096,38.407424])

share_error = np.array([0.0304501372235027,0.029076160472587,0.028624840625083,0.0284692821761486])
share_storage = np.array([6.130316,8.95994,11.789564,14.619188])

plt.title('Nyx')
plt.plot(interp_storage, interp_error, marker='o', label='interp')
plt.plot(Sz_storage, Sz_error, marker='o', label='SZ')
plt.plot(nonshare_storage, nonshare_error, marker='o', label='Ours(nonshare)', markersize=3)
plt.plot(share_storage, share_error, marker='o', label='Ours(share temporal)', markersize=3)
plt.xlabel('Storage(MB)')
plt.ylabel('RMSE')
comps_size = [3,6,9,12]

# for x,y,i in zip(interp_storage, interp_error, comps_size):
#     plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
for x,y,i in zip(nonshare_storage, nonshare_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#2ca02c')
for x,y,i in zip(share_storage, share_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#d62728')

plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
# Redsea compare thradeoff
# comps = [1,3,5,7]
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

Sz_error = np.array([0.131597335635112])
Sz_storage = np.array([38.62])

interp_error = np.array([0.01535387,0.011839502772252,0.00934451094976876,0.0076575344450405])
interp_storage = np.array([35.311,64.663456,116.031216,168.474])

nonshare_error = np.array([0.010615618584621,0.00894568145315,0.00854568741648657,0.005992656219106157])
nonshare_storage = np.array([35.311,77.684,120.058,162.431428])

share_error = np.array([0.00941411078829443,0.00791799459567337,0.00786342283563288,0.00784539096840246])
share_storage = np.array([31.246888,53.098516,65.83054,78.562564])

plt.title('Red Sea')
plt.plot(interp_storage, interp_error, marker='o', label='interp')
plt.plot(Sz_storage, Sz_error, marker='o', label='SZ')
plt.plot(nonshare_storage, nonshare_error, marker='o', label='Ours(nonshare)', markersize=3)
plt.plot(share_storage, share_error, marker='o', label='Ours(share temporal)', markersize=3)
plt.xlabel('Storage(MB)')
plt.ylabel('RMSE')
comps_size = [3,6,9,12]

# for x,y,i in zip(interp_storage, interp_error, comps_size):
#     plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
for x,y,i in zip(nonshare_storage, nonshare_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#2ca02c')
for x,y,i in zip(share_storage, share_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#d62728')

plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
# Global climate compare threshold
comps = [1,3,5,7]
constime150_error = np.array([0.0496565872450787,0.0492453403356508,0.0489248979110988,0.0472591058481787])
constime150_storage = np.array([4.61762,6.208652,7.799684,9.390716])

constime75_error = np.array([0.0492254363280651,0.0483358458635681,0.0400613292782127,0.0314649954388628])
constime75_storage = np.array([8.529,10.624008,12.719016,14.814024])

constime50_error = np.array([0.0489946609411116,0.0430768206503382,0.0310757548032218,0.0294359541925025])
constime50_storage = np.array([12.292808,14.70788,17.122952,19.538024])

# %%
plt.title('Global Climate')
plt.plot(constime150_storage, constime150_error, marker='o', label='time 150')
plt.plot(constime75_storage, constime75_error, marker='o', label='time 75')
plt.plot(constime50_storage, constime50_error, marker='o', label='time 50')
plt.xlabel('Storage(MB)')
plt.ylabel('RMSE')
comps_size = [1,5,8,12]

for x,y,i in zip(constime150_storage, constime150_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
for x,y,i in zip(constime75_storage, constime75_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#ff7f0e')
for x,y,i in zip(constime50_storage, constime50_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#2ca02c')

plt.legend()
plt.show()

# %%
plt.title('Global Climate')
plt.plot(comps, constime150_error, marker='o', label='time 150')
plt.plot(comps, constime75_error, marker='o', label='time 75')
plt.plot(comps, constime50_error, marker='o', label='time 50')
plt.xlabel('Number of components')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
# nyx compare threshold
comps = [1,3,5,7]
# thres5_error = np.array([0.0505528450356009,0.0313410857583633,0.0301851559990643,0.0296610073515932])
# thres5_storage = np.array([5.503076,8.7923,12.427316,16.062332])

# thres7_error = np.array([0.0505247584159693,0.0314735750556115,0.0303504168225438,0.029842327347302])
# thres7_storage = np.array([4.840208,7.841072,10.841936,13.8428])

# thres9_error = np.array([0.0505710176120438,0.0316203018962949,0.0305276941209006,0.0300314731177651])
# thres9_storage = np.array([4.614392,7.163624,9.712856,12.262088])

# thres12_error = np.array([0.0505860333763589,0.031796869884025,0.0307379445840375,0.0302568389713411])
# thres12_storage = np.array([4.38392,6.472208,8.560496,10.648784])


thres5_error = np.array([0.0313410857583633,0.0301851559990643,0.0296610073515932])
thres5_storage = np.array([8.7923,12.427316,16.062332])

thres7_error = np.array([0.0314735750556115,0.0303504168225438,0.029842327347302])
thres7_storage = np.array([7.841072,10.841936,13.8428])

thres9_error = np.array([0.0316203018962949,0.0305276941209006,0.0300314731177651])
thres9_storage = np.array([7.163624,9.712856,12.262088])

thres12_error = np.array([0.031796869884025,0.0307379445840375,0.0302568389713411])
thres12_storage = np.array([6.472208,8.560496,10.648784])

# %%
plt.title('Nyx')
plt.plot(thres5_storage, thres5_error, marker='o', label='thres 5',markersize=0)
plt.plot(thres7_storage, thres7_error, marker='o', label='thres 7',markersize=0)
plt.plot(thres9_storage, thres9_error, marker='o', label='thres 9',markersize=0)
plt.plot(thres12_storage, thres12_error, marker='o', label='thres 12',markersize=0)
plt.xlabel('Storage(MB)')
plt.ylabel('RMSE')
# plt.yticks(thres5_error,thres5_error)
comps_size = [5,9,13]

for x,y,i in zip(thres5_storage, thres5_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#1f77b4')
for x,y,i in zip(thres7_storage, thres7_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#ff7f0e')
for x,y,i in zip(thres9_storage, thres9_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#2ca02c')
for x,y,i in zip(thres12_storage, thres12_error, comps_size):
    plt.plot(x, y, marker='o', markersize=i, c = '#d62728')
# plt.ylim(2.9e-2,3.2e-2)
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
# Nyx compare threshold
comps = [1,3,5,7]
constime200_error = np.array([0.0506690721012931,0.031796869884025,0.0307379445840375,0.0302568389713411])
constime200_storage = np.array([4.38392,6.472208,8.560496,10.648784])

constime100_error = np.array([0.0405014395074497,0.0306534074402554,0.0300089623699006,0.0297260600576421])
constime100_storage = np.array([5.163852,7.304436,9.44502,11.585604])

constime50_error = np.array([0.0305766005477116,0.0292775428675196,0.0288578985264842,0.0287126852951448])
constime50_storage = np.array([5.736116,7.77734,9.81856399999999,11.859788])

# %%
plt.title('Nyx')
plt.plot(comps, constime200_error, marker='o', label='time 200')
plt.plot(comps, constime100_error, marker='o', label='time 100')
plt.plot(comps, constime50_error, marker='o', label='time 50')
plt.xlabel('Number of components')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
comps = [1,3,5,7]
constime60_error = np.array([0.0110045326512188,0.0101054371338895,0.00994634259987467,0.00984047780884513])
constime60_storage = np.array([4.38392,6.472208,8.560496,10.648784])

constime30_error = np.array([0.00950002543795074,0.00885483579423477,0.0087421941480732,0.00871629460369938])
constime30_storage = np.array([5.163852,7.304436,9.44502,11.585604])

constime20_error = np.array([0.00857404612113652,0.00802139465575991,0.00796717090725277,0.00794916907650585])
constime20_storage = np.array([5.736116,7.77734,9.81856399999999,11.859788])

plt.title('Red Sea')
plt.plot(comps, constime60_error, marker='o', label='time 60')
plt.plot(comps, constime30_error, marker='o', label='time 30')
plt.plot(comps, constime20_error, marker='o', label='time 20')
plt.xlabel('Number of components')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
#climate
climate_error_path = './error/Climate/'
os.listdir(climate_error_path)
# Out:
# ['climate_interp_sampletime10_error.bin',
#  'climate_interp_sampletime20_error.bin',
#  'climate_interp_sampletime30_error.bin',
#  'climate_interp_sampletime50_error.bin',
#  'Climate_sz_high_error.bin']

# %%
timestep = np.arange(0,50)
interp10 = np.fromfile(climate_error_path+'climate_interp_sampletime10_error.bin',dtype=np.float32)
interp20 = np.fromfile(climate_error_path+'climate_interp_sampletime20_error.bin',dtype=np.float32)
interp30 = np.fromfile(climate_error_path+'climate_interp_sampletime30_error.bin',dtype=np.float32)
interp50 = np.fromfile(climate_error_path+'climate_interp_sampletime50_error.bin',dtype=np.float32)
Sz_error = np.fromfile(climate_error_path+'Climate_sz_high_error.bin',dtype=np.float32)
Ours = np.fromfile(climate_error_path+'timesteps150_error.bin',dtype=np.float32)

plt.title('Global Climate')
plt.plot(timestep, Ours[:50], marker='o', label='Our approach')
# plt.plot(timestep, interp30[:50], marker='o', label='Interpolation:interval 30')
plt.plot(timestep, interp10[:50] , marker='s', markerfacecolor='None', label='Interpolation:interval 10')
plt.plot(timestep, Sz_error[:50] , marker='s', markerfacecolor='None', label='SZ lossy compraession')
plt.xlabel('Time Step')
plt.ylabel('Root Mean Square Error')
plt.ylim(0,0.2)
plt.legend()
plt.show()

# %%
#climate
Nyx_error_path = './error/Nyx/'
os.listdir(Nyx_error_path)
# Out:
# ['Nyx_interp_10_error.bin',
#  'Nyx_interp_20_error.bin',
#  'Nyx_interp_25_error.bin',
#  'Nyx_interp_5_error.bin',
#  'Nyx_interp_8_error.bin',
#  'Nyx_sz_high_error_error.bin',
#  'timesteps150_error.bin']

# %%
timestep = np.arange(0,50)
interp10 = np.fromfile(Nyx_error_path+'Nyx_interp_10_error.bin',dtype=np.float32)
interp20 = np.fromfile(Nyx_error_path+'Nyx_interp_20_error.bin',dtype=np.float32)
interp8 = np.fromfile(Nyx_error_path+'Nyx_interp_8_error.bin',dtype=np.float32)
Sz_error = np.fromfile(Nyx_error_path+'Nyx_sz_high_error_error.bin',dtype=np.float32)
Ours = np.fromfile(Nyx_error_path+'timesteps150_error.bin',dtype=np.float32)

plt.title('Nyx')
plt.plot(timestep, Ours[19:69], marker='o', label='Our approach')
# plt.plot(timestep, interp5[:50], marker='o', label='Interpolation:interval 30')
plt.plot(timestep, interp10[19:69] , marker='s', markerfacecolor='None', label='Interpolation:interval 10')
plt.plot(timestep, Sz_error[19:69] , marker='s', markerfacecolor='None', label='SZ lossy compraession')
plt.xlabel('Time Step')
plt.ylabel('Root Mean Square Error')
plt.legend()
plt.show()

# %%
interp10
# Out:
# array([0.        , 0.05677211, 0.0779969 , 0.01119383, 0.04670192,
#        0.06771605, 0.00752235, 0.04636818, 0.06424262, 0.        ,
#        0.04332926, 0.06172614, 0.03404416, 0.03608221, 0.06359167,
#        0.04610866, 0.01723595, 0.06024374, 0.06303579, 0.        ,
#        0.05160182, 0.07075731, 0.0222008 , 0.01969369, 0.05878404,
#        0.02920239, 0.02866027, 0.07435212, 0.04627131, 0.        ,
#        0.06060344, 0.05002876, 0.03278315, 0.06065131, 0.05946309,
#        0.0679303 , 0.07380217, 0.06662787, 0.06498396, 0.        ,
#        0.0613607 , 0.07148495, 0.02613643, 0.04755099, 0.07395492,
#        0.03492747, 0.04372295, 0.07863548, 0.05966377, 0.        ,
#        0.10152932, 0.09233303, 0.0803503 , 0.06857891, 0.07060545,
#        0.06536976, 0.03470621, 0.05111631, 0.05435465, 0.        ,
#        0.03650493, 0.0484232 , 0.02611439, 0.02906252, 0.05460967,
#        0.04366521, 0.01412615, 0.04838807, 0.05729597, 0.        ,
# ...

# %%
#redsea
redsea_error_path = './error/Redsea/'
os.listdir(Nyx_error_path)
# Out:
# ['Nyx_interp_10_error.bin',
#  'Nyx_interp_20_error.bin',
#  'Nyx_interp_25_error.bin',
#  'Nyx_interp_5_error.bin',
#  'Nyx_interp_8_error.bin',
#  'Nyx_sz_high_error_error.bin',
#  'timesteps150_error.bin']

# %%
timestep = np.arange(0,50)
interp10 = np.fromfile(redsea_error_path+'redsea_interp_sampletime10_error.bin',dtype=np.float32)
interp20 = np.fromfile(redsea_error_path+'redsea_interp_sampletime20_error.bin',dtype=np.float32)
interp5 = np.fromfile(redsea_error_path+'redsea_interp_sampletime5_error.bin',dtype=np.float32)
interp8 = np.fromfile(redsea_error_path+'redsea_interp_sampletime8_error.bin',dtype=np.float32)
Sz_error = np.fromfile(redsea_error_path+'RedSea_sz_high_error_error.bin',dtype=np.float32)
Ours = np.fromfile(redsea_error_path+'timesteps150_error.bin',dtype=np.float32)

plt.title('Red Sea')
plt.plot(timestep, Ours[:50], marker='o', label='Our approach')
# plt.plot(timestep, interp5[:50], marker='o', label='Interpolation:interval 30')
plt.plot(timestep, interp10[:50] , marker='s', markerfacecolor='None', label='Interpolation:interval 10')
# plt.plot(timestep, Sz_error[:50] , marker='s', markerfacecolor='None', label='SZ lossy compraession')
plt.xlabel('Time Step')
plt.ylabel('Root Mean Square Error')
plt.legend()
plt.show()
